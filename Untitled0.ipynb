# %% [markdown]
# <a href="https://colab.research.google.com/github/Coded-by-Disha/quantum_qiskit/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ---- Step 1: Install all required libraries ----
# !pip install -q qiskit qiskit-aer
# !pip install -q qiskit-machine-learning
# !pip install -q qiskit-algorithms
# !pip install -q pennylane pennylane-qiskit
# !pip install -q pylatexenc matplotlib numpy scikit-learn
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 41.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 66.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 94.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.1/263.1 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.8/327.8 kB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 1.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 34.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 937.5/937.5 kB 71.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.5/51.5 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.5/25.5 MB 70.9 MB/s eta 0:00:00
# ...

# %%
# ---- Step 2: Verify installation ----
import qiskit
import pennylane as qml
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.circuit.library import QFT, ZFeatureMap, ZZFeatureMap, RealAmplitudes

print("Qiskit version   :", qiskit.__version__)
print("PennyLane version:", qml.version())

# Quick test circuit
qc = QuantumCircuit(1, 1)
qc.h(0)
qc.measure(0, 0)
sim = AerSimulator()
result = sim.run(qc, shots=1000).result()
print("Test counts:", result.get_counts())
print("\nSetup successful. You can now run all 14 experiments.")
# Out:
# Qiskit version   : 2.3.0
# PennyLane version: 0.45.1
# Test counts: {'1': 515, '0': 485}
#
# Setup successful. You can now run all 14 experiments.

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram, plot_bloch_multivector
from qiskit.quantum_info import Statevector

sim = AerSimulator()

# 1) Pauli-X gate
qc_x = QuantumCircuit(1)
qc_x.x(0)
print("State after X gate:", Statevector(qc_x))

# 2) Hadamard gate
qc_h = QuantumCircuit(1)
qc_h.h(0)
print("State after H gate:", Statevector(qc_h))

# 3) Bell state (H + CNOT) -> entanglement
qc_bell = QuantumCircuit(2, 2)
qc_bell.h(0)
qc_bell.cx(0, 1)
qc_bell.measure([0, 1], [0, 1])

result = sim.run(qc_bell, shots=1000).result()
counts = result.get_counts()
print("Bell state measurement counts:", counts)
plot_histogram(counts)

simulator = AerSimulator()

job = simulator.run(qc, shots=1000)

result = job.result()

counts = result.get_counts()

print(counts)
# Out:
# State after X gate: Statevector([0.+0.j, 1.+0.j],
#             dims=(2,))
# State after H gate: Statevector([0.70710678+0.j, 0.70710678+0.j],
#             dims=(2,))
# Bell state measurement counts: {'00': 500, '11': 500}
# {'0': 495, '1': 505}
